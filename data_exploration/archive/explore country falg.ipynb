# %% [markdown]
# * Categorization numbers changed:
#
# country_flag
#
# US_ONLY         19255 --> 11120
#
# BOTH            16661 --> 24796
#
# FOREIGN_ONLY     2634 --> 3213
#
# NONE             2598 --> 2019
